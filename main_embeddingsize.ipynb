# %%
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import spacy
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from spacy.lang.en.stop_words import STOP_WORDS

warnings.filterwarnings('ignore')

# %%
# Load the dataset 
df = pd.read_csv("https://full-stack-bigdata-datasets.s3.eu-west-3.amazonaws.com/Deep+Learning/project/spam.csv", error_bad_lines=False, encoding="ISO-8859-1")

# %%
# Display basic information about the dataset
print(df.info())
print(df.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB
# None
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                Unnamed: 2  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                    Unnamed: 3 Unnamed: 4
# count                      12          6
# unique                     10          5
# top      MK17 92H. 450Ppw 16"    GNT:-)"
# freq                        2          2

# %%
# Amount of missing values
def missing_values(df, norows):   # input by the df and the number of rows that you want to show  
    total = df.isnull().sum().sort_values(ascending=False)  
    percent = ((df.isnull().sum().sort_values(ascending=False)/df.shape[0])*100).sort_values(ascending=False)  
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])  
    return(missing_data.head(norows))  
  
missing_values(df,20) # we use the df and the number of rows to show is 20
# Out:
#             Total    Percent
# Unnamed: 4   5566  99.892319
# Unnamed: 3   5560  99.784637
# Unnamed: 2   5522  99.102656
# v1              0   0.000000
# v2              0   0.000000

# %%
# Remove useless columns and rename v1 and v2 columns
df = df.rename(columns={"v1": "type", "v2": "message"})
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# %%
# Visualize the distribution of spam and ham messages
plt.figure(figsize=(8, 6))
sns.countplot(x='type', data=df)
plt.title('Distribution of Spam and Ham Messages')
plt.xlabel('Message Type')
plt.ylabel('Count')
plt.show()

# %%
# Change dtype of type column to category
df = df.astype({"type": "category"})

# Drop duplicates
df.drop_duplicates(inplace=True)

# Replace ham and spam by 0 and 1
df['type'] = df['type'].map({'ham': 0, 'spam': 1})

# %%
# Preprocessing - cleaning the text
nlp = spacy.load('en_core_web_md')

# Remove special characters, convert to lowercase, and lemmatize words
df['mail_cleaned'] = (
    df['message']
    .apply(lambda x:''.join(ch for ch in x if ch.isalnum() or ch==" " or ch=="'"))
    .str.lower()
    .str.strip()
    .str.replace('\s\s+', ' ')
    .apply(lambda x: " ".join([token.lemma_ for token in nlp(x) if (token.lemma_ not in STOP_WORDS) and (token.text not in STOP_WORDS)]))
)

df.head()
# Out:
#   type                                            message  \
# 0    0  Go until jurong point, crazy.. Available only ...
# 1    0                      Ok lar... Joking wif u oni...
# 2    1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    0  U dun say so early hor... U c already then say...
# 4    0  Nah I don't think he goes to usf, he lives aro...
#
#                                         mail_cleaned
# 0  jurong point crazy available bugis n great wor...
# 1                              ok lar joke wif u oni
# 2  free entry 2 wkly comp win fa cup final tkts 2...
# 3                                u dun early hor u c
# 4                                 nah think usf live

# %%
# Tokenize the cleaned text
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=1000, oov_token="out_of_vocab")
tokenizer.fit_on_texts(df.mail_cleaned)
df["mail_encoded"] = tokenizer.texts_to_sequences(df.mail_cleaned)
df.head()
# Out:
#   type                                            message  \
# 0    0  Go until jurong point, crazy.. Available only ...
# 1    0                      Ok lar... Joking wif u oni...
# 2    1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    0  U dun say so early hor... U c already then say...
# 4    0  Nah I don't think he goes to usf, he lives aro...
#
#                                         mail_cleaned  \
# 0  jurong point crazy available bugis n great wor...
# 1                              ok lar joke wif u oni
# 2  free entry 2 wkly comp win fa cup final tkts 2...
# 3                                u dun early hor u c
# 4                                 nah think usf live
#
#                                         mail_encoded
# 0  [1, 214, 409, 485, 845, 32, 52, 264, 846, 74, ...
# 1                          [10, 176, 486, 265, 2, 1]
# 2  [11, 338, 3, 698, 699, 39, 1, 976, 458, 1, 1, ...
# 3                            [2, 114, 135, 1, 2, 78]
# 4                                [662, 20, 597, 147]

# %%
# Pad the sequences
messages_pad = tf.keras.preprocessing.sequence.pad_sequences(df.mail_encoded, padding="post")

# Train-test split
xtrain, xval, ytrain, yval = train_test_split(messages_pad, df.type, test_size=0.3, random_state=42)

# %%
# Create tf.data datasets for training and validation
train = tf.data.Dataset.from_tensor_slices((xtrain, ytrain))
val = tf.data.Dataset.from_tensor_slices((xval, yval))

train_batch = train.shuffle(len(train)).batch(64)
val_batch = val.shuffle(len(val)).batch(64)
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2023-04-05 11:16:34.074141: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-04-05 11:16:34.074752: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Define the model architecture
vocab_size = tokenizer.num_words
model = tf.keras.Sequential([
    # Input Word Embedding layer
    tf.keras.layers.Embedding(vocab_size+1, 32, input_shape=[None,], name="embedding"),
    # Global average pooling
    tf.keras.layers.GlobalAveragePooling1D(),
    # Dense layer
    tf.keras.layers.Dense(16, activation='relu'),
    # Output layer
    tf.keras.layers.Dense(1, activation="sigmoid")  # changed activation to sigmoid for binary classification
])

# Compile the model
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[tf.keras.metrics.BinaryAccuracy()]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 8)           8008
#
#  global_average_pooling1d (G  (None, 8)                0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                144
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 8,169
# Trainable params: 8,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define the tensorboard callback
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="logs")

# Define the early stopping callback
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# Train the model with early stopping and tensorboard callbacks
history = model.fit(
    train_batch,
    epochs=100,
    validation_data=val_batch,
    callbacks=[tensorboard_callback, early_stop]
)
# Out:
# Epoch 1/100
# 2023-04-05 11:16:34.621088: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-04-05 11:16:34.622659: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 57/57 [==============================] - ETA: 0s - loss: 0.6478 - binary_accuracy: 0.8416
# 2023-04-05 11:16:36.735602: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 57/57 [==============================] - 3s 31ms/step - loss: 0.6478 - binary_accuracy: 0.8416 - val_loss: 0.5903 - val_binary_accuracy: 0.8582
# Epoch 2/100
# 57/57 [==============================] - 1s 23ms/step - loss: 0.5067 - binary_accuracy: 0.8803 - val_loss: 0.4505 - val_binary_accuracy: 0.8582
# Epoch 3/100
# 57/57 [==============================] - 1s 21ms/step - loss: 0.3837 - binary_accuracy: 0.8803 - val_loss: 0.3848 - val_binary_accuracy: 0.8582
# Epoch 4/100
# 57/57 [==============================] - 1s 22ms/step - loss: 0.3401 - binary_accuracy: 0.8803 - val_loss: 0.3725 - val_binary_accuracy: 0.8582
# Epoch 5/100
# 57/57 [==============================] - 1s 23ms/step - loss: 0.3284 - binary_accuracy: 0.8803 - val_loss: 0.3638 - val_binary_accuracy: 0.8582
# Epoch 6/100
# 57/57 [==============================] - 1s 24ms/step - loss: 0.3194 - binary_accuracy: 0.8803 - val_loss: 0.3545 - val_binary_accuracy: 0.8582
# Epoch 7/100
# 57/57 [==============================] - 1s 21ms/step - loss: 0.3097 - binary_accuracy: 0.8803 - val_loss: 0.3427 - val_binary_accuracy: 0.8582
# Epoch 8/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.2985 - binary_accuracy: 0.8803 - val_loss: 0.3294 - val_binary_accuracy: 0.8582
# Epoch 9/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.2853 - binary_accuracy: 0.8803 - val_loss: 0.3130 - val_binary_accuracy: 0.8582
# Epoch 10/100
# 57/57 [==============================] - 1s 21ms/step - loss: 0.2694 - binary_accuracy: 0.8803 - val_loss: 0.2927 - val_binary_accuracy: 0.8582
# Epoch 11/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.2503 - binary_accuracy: 0.8803 - val_loss: 0.2696 - val_binary_accuracy: 0.8582
# Epoch 12/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.2308 - binary_accuracy: 0.8803 - val_loss: 0.2491 - val_binary_accuracy: 0.8582
# Epoch 13/100
# 57/57 [==============================] - 1s 21ms/step - loss: 0.2128 - binary_accuracy: 0.8803 - val_loss: 0.2284 - val_binary_accuracy: 0.8582
# Epoch 14/100
# 57/57 [==============================] - 1s 24ms/step - loss: 0.1985 - binary_accuracy: 0.8803 - val_loss: 0.2160 - val_binary_accuracy: 0.8582
# Epoch 15/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1873 - binary_accuracy: 0.8803 - val_loss: 0.2027 - val_binary_accuracy: 0.8582
# Epoch 16/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1783 - binary_accuracy: 0.8803 - val_loss: 0.1934 - val_binary_accuracy: 0.8582
# Epoch 17/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1708 - binary_accuracy: 0.8803 - val_loss: 0.1881 - val_binary_accuracy: 0.8582
# Epoch 18/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1650 - binary_accuracy: 0.9151 - val_loss: 0.1800 - val_binary_accuracy: 0.9304
# Epoch 19/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1596 - binary_accuracy: 0.9467 - val_loss: 0.1741 - val_binary_accuracy: 0.9394
# Epoch 20/100
# 57/57 [==============================] - 1s 21ms/step - loss: 0.1545 - binary_accuracy: 0.9494 - val_loss: 0.1694 - val_binary_accuracy: 0.9478
# Epoch 21/100
# 57/57 [==============================] - 1s 21ms/step - loss: 0.1500 - binary_accuracy: 0.9569 - val_loss: 0.1665 - val_binary_accuracy: 0.9426
# Epoch 22/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1459 - binary_accuracy: 0.9583 - val_loss: 0.1609 - val_binary_accuracy: 0.9536
# Epoch 23/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1419 - binary_accuracy: 0.9613 - val_loss: 0.1574 - val_binary_accuracy: 0.9542
# Epoch 24/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1381 - binary_accuracy: 0.9621 - val_loss: 0.1539 - val_binary_accuracy: 0.9568
# Epoch 25/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1346 - binary_accuracy: 0.9632 - val_loss: 0.1509 - val_binary_accuracy: 0.9574
# Epoch 26/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1308 - binary_accuracy: 0.9666 - val_loss: 0.1486 - val_binary_accuracy: 0.9581
# Epoch 27/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1275 - binary_accuracy: 0.9677 - val_loss: 0.1458 - val_binary_accuracy: 0.9600
# Epoch 28/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1241 - binary_accuracy: 0.9690 - val_loss: 0.1421 - val_binary_accuracy: 0.9658
# Epoch 29/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1207 - binary_accuracy: 0.9713 - val_loss: 0.1401 - val_binary_accuracy: 0.9665
# Epoch 30/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1174 - binary_accuracy: 0.9718 - val_loss: 0.1372 - val_binary_accuracy: 0.9678
# Epoch 31/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1141 - binary_accuracy: 0.9729 - val_loss: 0.1342 - val_binary_accuracy: 0.9684
# Epoch 32/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1107 - binary_accuracy: 0.9740 - val_loss: 0.1313 - val_binary_accuracy: 0.9691
# Epoch 33/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1074 - binary_accuracy: 0.9773 - val_loss: 0.1295 - val_binary_accuracy: 0.9703
# Epoch 34/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1046 - binary_accuracy: 0.9760 - val_loss: 0.1262 - val_binary_accuracy: 0.9736
# Epoch 35/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1019 - binary_accuracy: 0.9787 - val_loss: 0.1249 - val_binary_accuracy: 0.9703
# Epoch 36/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0984 - binary_accuracy: 0.9798 - val_loss: 0.1212 - val_binary_accuracy: 0.9755
# Epoch 37/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0957 - binary_accuracy: 0.9815 - val_loss: 0.1194 - val_binary_accuracy: 0.9755
# Epoch 38/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0927 - binary_accuracy: 0.9815 - val_loss: 0.1182 - val_binary_accuracy: 0.9755
# Epoch 39/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0905 - binary_accuracy: 0.9815 - val_loss: 0.1156 - val_binary_accuracy: 0.9761
# Epoch 40/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0878 - binary_accuracy: 0.9837 - val_loss: 0.1149 - val_binary_accuracy: 0.9755
# Epoch 41/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0852 - binary_accuracy: 0.9831 - val_loss: 0.1110 - val_binary_accuracy: 0.9781
# Epoch 42/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0804 - binary_accuracy: 0.9834 - val_loss: 0.1028 - val_binary_accuracy: 0.9800
# Epoch 43/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0712 - binary_accuracy: 0.9856 - val_loss: 0.0935 - val_binary_accuracy: 0.9787
# Epoch 44/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0630 - binary_accuracy: 0.9865 - val_loss: 0.0855 - val_binary_accuracy: 0.9800
# Epoch 45/100
# 57/57 [==============================] - 1s 21ms/step - loss: 0.0563 - binary_accuracy: 0.9873 - val_loss: 0.0831 - val_binary_accuracy: 0.9787
# Epoch 46/100
# 57/57 [==============================] - 1s 21ms/step - loss: 0.0507 - binary_accuracy: 0.9884 - val_loss: 0.0779 - val_binary_accuracy: 0.9781
# Epoch 47/100
# 57/57 [==============================] - 1s 22ms/step - loss: 0.0463 - binary_accuracy: 0.9881 - val_loss: 0.0716 - val_binary_accuracy: 0.9807
# Epoch 48/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0434 - binary_accuracy: 0.9898 - val_loss: 0.0705 - val_binary_accuracy: 0.9813
# Epoch 49/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0405 - binary_accuracy: 0.9898 - val_loss: 0.0676 - val_binary_accuracy: 0.9794
# Epoch 50/100
# 57/57 [==============================] - 1s 21ms/step - loss: 0.0384 - binary_accuracy: 0.9903 - val_loss: 0.0676 - val_binary_accuracy: 0.9807
# Epoch 51/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0363 - binary_accuracy: 0.9909 - val_loss: 0.0664 - val_binary_accuracy: 0.9807
# Epoch 52/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0345 - binary_accuracy: 0.9903 - val_loss: 0.0645 - val_binary_accuracy: 0.9794
# Epoch 53/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0330 - binary_accuracy: 0.9914 - val_loss: 0.0655 - val_binary_accuracy: 0.9807
# Epoch 54/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0321 - binary_accuracy: 0.9909 - val_loss: 0.0639 - val_binary_accuracy: 0.9800
# Epoch 55/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0306 - binary_accuracy: 0.9912 - val_loss: 0.0633 - val_binary_accuracy: 0.9800
# Epoch 56/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0297 - binary_accuracy: 0.9920 - val_loss: 0.0636 - val_binary_accuracy: 0.9800
# Epoch 57/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0290 - binary_accuracy: 0.9914 - val_loss: 0.0630 - val_binary_accuracy: 0.9807
# Epoch 58/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0276 - binary_accuracy: 0.9920 - val_loss: 0.0640 - val_binary_accuracy: 0.9807
# Epoch 59/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0264 - binary_accuracy: 0.9925 - val_loss: 0.0622 - val_binary_accuracy: 0.9800
# Epoch 60/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0254 - binary_accuracy: 0.9923 - val_loss: 0.0620 - val_binary_accuracy: 0.9807
# Epoch 61/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0249 - binary_accuracy: 0.9931 - val_loss: 0.0645 - val_binary_accuracy: 0.9807
# Epoch 62/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0234 - binary_accuracy: 0.9931 - val_loss: 0.0664 - val_binary_accuracy: 0.9813
# Epoch 63/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0229 - binary_accuracy: 0.9925 - val_loss: 0.0648 - val_binary_accuracy: 0.9813
# Epoch 64/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0226 - binary_accuracy: 0.9934 - val_loss: 0.0682 - val_binary_accuracy: 0.9819
# Epoch 65/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0216 - binary_accuracy: 0.9934 - val_loss: 0.0633 - val_binary_accuracy: 0.9813
# Epoch 66/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0208 - binary_accuracy: 0.9939 - val_loss: 0.0633 - val_binary_accuracy: 0.9807
# Epoch 67/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0201 - binary_accuracy: 0.9945 - val_loss: 0.0627 - val_binary_accuracy: 0.9819
# Epoch 68/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0199 - binary_accuracy: 0.9939 - val_loss: 0.0635 - val_binary_accuracy: 0.9819
# Epoch 69/100
# 57/57 [==============================] - 1s 22ms/step - loss: 0.0190 - binary_accuracy: 0.9945 - val_loss: 0.0668 - val_binary_accuracy: 0.9813
# Epoch 70/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0183 - binary_accuracy: 0.9945 - val_loss: 0.0663 - val_binary_accuracy: 0.9819

# %%
# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(val_batch)
print("Validation loss: ", val_loss)
print("Validation accuracy: ", val_accuracy)
# Out:
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0663 - binary_accuracy: 0.9819
# Validation loss:  0.06627298146486282
# Validation accuracy:  0.9819471836090088

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(14, 4))

# Plot training and validation loss
ax1.plot(history.history['loss'], label='Training Loss')
ax1.plot(history.history['val_loss'], label='Validation Loss')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

plt.show()

# %%
fig, ax2 = plt.subplots(1, 1, figsize=(14, 4))

# Plot training and validation accuracy
ax2.plot(history.history['binary_accuracy'], label='Training Accuracy')
ax2.plot(history.history['val_binary_accuracy'], label='Validation Accuracy')
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.show()

# %%
# Predict the probabilities on the validation set
y_pred_probs = model.predict(xval)

# Apply a threshold (0.5) to obtain class labels
y_pred = (y_pred_probs > 0.5).astype(int).reshape(-1)

# Compute the confusion matrix
cm = confusion_matrix(yval, y_pred)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks([0.5, 1.5], ['Ham', 'Spam'])
plt.yticks([0.5, 1.5], ['Ham', 'Spam'], va='center')
plt.show()
# Out:
# 49/49 [==============================] - 0s 3ms/step
# 2023-04-05 11:29:09.776612: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
