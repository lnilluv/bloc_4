# %%
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import spacy
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from spacy.lang.en.stop_words import STOP_WORDS

warnings.filterwarnings('ignore')

# %%
# Load the dataset
df = pd.read_csv("https://full-stack-bigdata-datasets.s3.eu-west-3.amazonaws.com/Deep+Learning/project/spam.csv", error_bad_lines=False, encoding="ISO-8859-1")

# %%
# Display basic information about the dataset
print(df.info())
print(df.describe(include='all'))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB
# None
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                Unnamed: 2  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                    Unnamed: 3 Unnamed: 4
# count                      12          6
# unique                     10          5
# top      MK17 92H. 450Ppw 16"    GNT:-)"
# freq                        2          2

# %%
# Amount of missing values
def missing_values(df, norows):   # input by the df and the number of rows that you want to show  
    total = df.isnull().sum().sort_values(ascending=False)  
    percent = ((df.isnull().sum().sort_values(ascending=False)/df.shape[0])*100).sort_values(ascending=False)  
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])  
    return(missing_data.head(norows))  
  
missing_values(df,20) # we use the df and the number of rows to show is 20
# Out:
#             Total    Percent
# Unnamed: 4   5566  99.892319
# Unnamed: 3   5560  99.784637
# Unnamed: 2   5522  99.102656
# v1              0   0.000000
# v2              0   0.000000

# %%
# Remove useless columns and rename v1 and v2 columns
df = df.rename(columns={"v1": "type", "v2": "message"})
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# %%
# Visualize the distribution of spam and ham messages
plt.figure(figsize=(8, 6))
sns.countplot(x='type', data=df)
plt.title('Distribution of Spam and Ham Messages')
plt.xlabel('Message Type')
plt.ylabel('Count')
plt.show()

# %%
# Change dtype of type column to category
df = df.astype({"type": "category"})

# Drop duplicates
df.drop_duplicates(inplace=True)

# Replace ham and spam by 0 and 1
df['type'] = df['type'].map({'ham': 0, 'spam': 1})

# %%
# Preprocessing - cleaning the text
nlp = spacy.load('en_core_web_md')

# Remove special characters, convert to lowercase, and lemmatize words
df['mail_cleaned'] = (
    df['message']
    .apply(lambda x:''.join(ch for ch in x if ch.isalnum() or ch==" " or ch=="'"))
    .str.lower()
    .str.strip()
    .str.replace('\s\s+', ' ')
    .apply(lambda x: " ".join([token.lemma_ for token in nlp(x) if (token.lemma_ not in STOP_WORDS) and (token.text not in STOP_WORDS)]))
)

df.head()
# Out:
#   type                                            message  \
# 0    0  Go until jurong point, crazy.. Available only ...
# 1    0                      Ok lar... Joking wif u oni...
# 2    1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    0  U dun say so early hor... U c already then say...
# 4    0  Nah I don't think he goes to usf, he lives aro...
#
#                                         mail_cleaned
# 0  jurong point crazy available bugis n great wor...
# 1                              ok lar joke wif u oni
# 2  free entry 2 wkly comp win fa cup final tkts 2...
# 3                                u dun early hor u c
# 4                                 nah think usf live

# %%
# Tokenize the cleaned text
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=1000, oov_token="out_of_vocab")
tokenizer.fit_on_texts(df.mail_cleaned)
df["mail_encoded"] = tokenizer.texts_to_sequences(df.mail_cleaned)
df.head()
# Out:
#   type                                            message  \
# 0    0  Go until jurong point, crazy.. Available only ...
# 1    0                      Ok lar... Joking wif u oni...
# 2    1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    0  U dun say so early hor... U c already then say...
# 4    0  Nah I don't think he goes to usf, he lives aro...
#
#                                         mail_cleaned  \
# 0  jurong point crazy available bugis n great wor...
# 1                              ok lar joke wif u oni
# 2  free entry 2 wkly comp win fa cup final tkts 2...
# 3                                u dun early hor u c
# 4                                 nah think usf live
#
#                                         mail_encoded
# 0  [1, 214, 409, 485, 845, 32, 52, 264, 846, 74, ...
# 1                          [10, 176, 486, 265, 2, 1]
# 2  [11, 338, 3, 698, 699, 39, 1, 976, 458, 1, 1, ...
# 3                            [2, 114, 135, 1, 2, 78]
# 4                                [662, 20, 597, 147]

# %%
# Pad the sequences
messages_pad = tf.keras.preprocessing.sequence.pad_sequences(df.mail_encoded, padding="post")

# Train-test split
xtrain, xval, ytrain, yval = train_test_split(messages_pad, df.type, test_size=0.3, random_state=42)

# %%
# Create tf.data datasets for training and validation
train = tf.data.Dataset.from_tensor_slices((xtrain, ytrain))
val = tf.data.Dataset.from_tensor_slices((xval, yval))

train_batch = train.shuffle(len(train)).batch(64)
val_batch = val.shuffle(len(val)).batch(64)

# %%
# Define the model architecture
vocab_size = tokenizer.num_words
max_len = messages_pad.shape[1]
model = tf.keras.Sequential([
    # Input Word Embedding layer
    tf.keras.layers.Embedding(vocab_size+1, 8, input_length=max_len, name="embedding"),
    # Global average pooling
    tf.keras.layers.GlobalAveragePooling1D(),
    # Dense layer
    tf.keras.layers.Dense(16, activation='relu'),
    # Output layer
    tf.keras.layers.Dense(1, activation="sigmoid")  # changed activation to sigmoid for binary classification
])

# Compile the model
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=[tf.keras.metrics.BinaryAccuracy()]
)

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 74, 8)             8008
#
#  global_average_pooling1d_1   (None, 8)                0
#  (GlobalAveragePooling1D)
#
#  dense_2 (Dense)             (None, 16)                144
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 8,169
# Trainable params: 8,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define the tensorboard callback
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir="logs")

# Define the early stopping callback
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

# Train the model with early stopping and tensorboard callbacks
history = model.fit(
    train_batch,
    epochs=100,
    validation_data=val_batch,
    callbacks=[tensorboard_callback, early_stop]
)
# Out:
# Epoch 1/100
# 2023-04-05 12:09:50.843771: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 57/57 [==============================] - ETA: 0s - loss: 0.6400 - binary_accuracy: 0.8679
# 2023-04-05 12:09:53.013470: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 57/57 [==============================] - 3s 39ms/step - loss: 0.6400 - binary_accuracy: 0.8679 - val_loss: 0.5917 - val_binary_accuracy: 0.8582
# Epoch 2/100
# 57/57 [==============================] - 1s 24ms/step - loss: 0.5192 - binary_accuracy: 0.8803 - val_loss: 0.4674 - val_binary_accuracy: 0.8582
# Epoch 3/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.3986 - binary_accuracy: 0.8803 - val_loss: 0.3915 - val_binary_accuracy: 0.8582
# Epoch 4/100
# 57/57 [==============================] - 1s 21ms/step - loss: 0.3454 - binary_accuracy: 0.8803 - val_loss: 0.3743 - val_binary_accuracy: 0.8582
# Epoch 5/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.3309 - binary_accuracy: 0.8803 - val_loss: 0.3666 - val_binary_accuracy: 0.8582
# Epoch 6/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.3225 - binary_accuracy: 0.8803 - val_loss: 0.3580 - val_binary_accuracy: 0.8582
# Epoch 7/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.3141 - binary_accuracy: 0.8803 - val_loss: 0.3484 - val_binary_accuracy: 0.8582
# Epoch 8/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.3046 - binary_accuracy: 0.8803 - val_loss: 0.3378 - val_binary_accuracy: 0.8582
# Epoch 9/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.2935 - binary_accuracy: 0.8803 - val_loss: 0.3231 - val_binary_accuracy: 0.8582
# Epoch 10/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.2796 - binary_accuracy: 0.8803 - val_loss: 0.3054 - val_binary_accuracy: 0.8582
# Epoch 11/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.2608 - binary_accuracy: 0.8803 - val_loss: 0.2787 - val_binary_accuracy: 0.8582
# Epoch 12/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.2334 - binary_accuracy: 0.8861 - val_loss: 0.2419 - val_binary_accuracy: 0.8717
# Epoch 13/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.2012 - binary_accuracy: 0.9118 - val_loss: 0.2046 - val_binary_accuracy: 0.9046
# Epoch 14/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1710 - binary_accuracy: 0.9367 - val_loss: 0.1713 - val_binary_accuracy: 0.9349
# Epoch 15/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.1466 - binary_accuracy: 0.9497 - val_loss: 0.1478 - val_binary_accuracy: 0.9471
# Epoch 16/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.1296 - binary_accuracy: 0.9580 - val_loss: 0.1310 - val_binary_accuracy: 0.9549
# Epoch 17/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.1165 - binary_accuracy: 0.9613 - val_loss: 0.1191 - val_binary_accuracy: 0.9632
# Epoch 18/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.1065 - binary_accuracy: 0.9657 - val_loss: 0.1105 - val_binary_accuracy: 0.9632
# Epoch 19/100
# 57/57 [==============================] - 1s 22ms/step - loss: 0.0974 - binary_accuracy: 0.9679 - val_loss: 0.1021 - val_binary_accuracy: 0.9671
# Epoch 20/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0907 - binary_accuracy: 0.9699 - val_loss: 0.0950 - val_binary_accuracy: 0.9703
# Epoch 21/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0833 - binary_accuracy: 0.9735 - val_loss: 0.0904 - val_binary_accuracy: 0.9710
# Epoch 22/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0777 - binary_accuracy: 0.9748 - val_loss: 0.0847 - val_binary_accuracy: 0.9716
# Epoch 23/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0728 - binary_accuracy: 0.9779 - val_loss: 0.0840 - val_binary_accuracy: 0.9742
# Epoch 24/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0685 - binary_accuracy: 0.9768 - val_loss: 0.0768 - val_binary_accuracy: 0.9742
# Epoch 25/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0645 - binary_accuracy: 0.9801 - val_loss: 0.0740 - val_binary_accuracy: 0.9742
# Epoch 26/100
# 57/57 [==============================] - 1s 22ms/step - loss: 0.0611 - binary_accuracy: 0.9801 - val_loss: 0.0714 - val_binary_accuracy: 0.9761
# Epoch 27/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0581 - binary_accuracy: 0.9818 - val_loss: 0.0706 - val_binary_accuracy: 0.9761
# Epoch 28/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0547 - binary_accuracy: 0.9826 - val_loss: 0.0676 - val_binary_accuracy: 0.9781
# Epoch 29/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0524 - binary_accuracy: 0.9845 - val_loss: 0.0660 - val_binary_accuracy: 0.9781
# Epoch 30/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0499 - binary_accuracy: 0.9856 - val_loss: 0.0648 - val_binary_accuracy: 0.9787
# Epoch 31/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0479 - binary_accuracy: 0.9865 - val_loss: 0.0644 - val_binary_accuracy: 0.9787
# Epoch 32/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0454 - binary_accuracy: 0.9856 - val_loss: 0.0630 - val_binary_accuracy: 0.9787
# Epoch 33/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0441 - binary_accuracy: 0.9873 - val_loss: 0.0626 - val_binary_accuracy: 0.9787
# Epoch 34/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0424 - binary_accuracy: 0.9878 - val_loss: 0.0613 - val_binary_accuracy: 0.9787
# Epoch 35/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0404 - binary_accuracy: 0.9876 - val_loss: 0.0617 - val_binary_accuracy: 0.9787
# Epoch 36/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0396 - binary_accuracy: 0.9892 - val_loss: 0.0612 - val_binary_accuracy: 0.9787
# Epoch 37/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0377 - binary_accuracy: 0.9892 - val_loss: 0.0614 - val_binary_accuracy: 0.9787
# Epoch 38/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0363 - binary_accuracy: 0.9903 - val_loss: 0.0600 - val_binary_accuracy: 0.9787
# Epoch 39/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0352 - binary_accuracy: 0.9903 - val_loss: 0.0596 - val_binary_accuracy: 0.9800
# Epoch 40/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0338 - binary_accuracy: 0.9912 - val_loss: 0.0597 - val_binary_accuracy: 0.9800
# Epoch 41/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0325 - binary_accuracy: 0.9903 - val_loss: 0.0589 - val_binary_accuracy: 0.9787
# Epoch 42/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0324 - binary_accuracy: 0.9912 - val_loss: 0.0603 - val_binary_accuracy: 0.9800
# Epoch 43/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0314 - binary_accuracy: 0.9912 - val_loss: 0.0586 - val_binary_accuracy: 0.9794
# Epoch 44/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0296 - binary_accuracy: 0.9914 - val_loss: 0.0585 - val_binary_accuracy: 0.9794
# Epoch 45/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0288 - binary_accuracy: 0.9914 - val_loss: 0.0594 - val_binary_accuracy: 0.9800
# Epoch 46/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0279 - binary_accuracy: 0.9917 - val_loss: 0.0601 - val_binary_accuracy: 0.9800
# Epoch 47/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0277 - binary_accuracy: 0.9920 - val_loss: 0.0587 - val_binary_accuracy: 0.9807
# Epoch 48/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0269 - binary_accuracy: 0.9931 - val_loss: 0.0589 - val_binary_accuracy: 0.9807
# Epoch 49/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0261 - binary_accuracy: 0.9914 - val_loss: 0.0587 - val_binary_accuracy: 0.9807
# Epoch 50/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0253 - binary_accuracy: 0.9928 - val_loss: 0.0582 - val_binary_accuracy: 0.9800
# Epoch 51/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0245 - binary_accuracy: 0.9928 - val_loss: 0.0584 - val_binary_accuracy: 0.9800
# Epoch 52/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0236 - binary_accuracy: 0.9925 - val_loss: 0.0591 - val_binary_accuracy: 0.9807
# Epoch 53/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0229 - binary_accuracy: 0.9934 - val_loss: 0.0600 - val_binary_accuracy: 0.9807
# Epoch 54/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0223 - binary_accuracy: 0.9928 - val_loss: 0.0586 - val_binary_accuracy: 0.9807
# Epoch 55/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0221 - binary_accuracy: 0.9936 - val_loss: 0.0590 - val_binary_accuracy: 0.9813
# Epoch 56/100
# 57/57 [==============================] - 1s 24ms/step - loss: 0.0212 - binary_accuracy: 0.9934 - val_loss: 0.0596 - val_binary_accuracy: 0.9807
# Epoch 57/100
# 57/57 [==============================] - 1s 22ms/step - loss: 0.0205 - binary_accuracy: 0.9939 - val_loss: 0.0622 - val_binary_accuracy: 0.9813
# Epoch 58/100
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0203 - binary_accuracy: 0.9934 - val_loss: 0.0599 - val_binary_accuracy: 0.9813
# Epoch 59/100
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0193 - binary_accuracy: 0.9942 - val_loss: 0.0623 - val_binary_accuracy: 0.9813
# Epoch 60/100
# 57/57 [==============================] - 1s 18ms/step - loss: 0.0191 - binary_accuracy: 0.9939 - val_loss: 0.0661 - val_binary_accuracy: 0.9813

# %%
# Evaluate the model on the validation set
val_loss, val_accuracy = model.evaluate(val_batch)
print("Validation loss: ", val_loss)
print("Validation accuracy: ", val_accuracy)
# Out:
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0661 - binary_accuracy: 0.9813
# Validation loss:  0.06605399399995804
# Validation accuracy:  0.9813024401664734

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(14, 4))

# Plot training and validation loss
ax1.plot(history.history['loss'], label='Training Loss')
ax1.plot(history.history['val_loss'], label='Validation Loss')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()

plt.show()

# %%
fig, ax2 = plt.subplots(1, 1, figsize=(14, 4))

# Plot training and validation accuracy
ax2.plot(history.history['binary_accuracy'], label='Training Accuracy')
ax2.plot(history.history['val_binary_accuracy'], label='Validation Accuracy')
ax2.set_title('Training and Validation Accuracy')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Accuracy')
ax2.legend()

plt.show()

# %%
# Predict the probabilities on the validation set
y_pred_probs = model.predict(xval)

# Apply a threshold (0.5) to obtain class labels
y_pred = (y_pred_probs > 0.5).astype(int).reshape(-1)

# Compute the confusion matrix
cm = confusion_matrix(yval, y_pred)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.xticks([0.5, 1.5], ['Ham', 'Spam'])
plt.yticks([0.5, 1.5], ['Ham', 'Spam'], va='center')
plt.show()
# Out:
# 49/49 [==============================] - 0s 2ms/step
# 2023-04-05 12:10:59.029546: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
